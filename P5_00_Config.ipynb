# %%
SOURCE_TABLE_OIL = "workspace.default.oil"
SOURCE_TABLE_HOLIDAYS = "workspace.default.holidays_events"
SOURCE_TABLE_SALES = "workspace.default.train"

# %%
BRONZE_SALES = "workspace.default.p5_bronze_sales"
BRONZE_HOLIDAYS = "workspace.default.p5_bronze_holidays"
BRONZE_OIL = "workspace.default.p5_bronze_oil"

# %%
SILVER_TABLE = "workspace.default.p5_silver_sales"
GOLD_TABLE = "workspace.default.p5_gold_forecast"

AUDIT_TABLE = "workspace.default.p5_audit"

# %%
#Run ID and model parameters

import uuid

RUN_ID = str(uuid.uuid4())

FORECAST_HORIZON = 30
DATE_COL = "date"
TARGET_COL = "sales"
